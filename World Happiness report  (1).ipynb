# %% [markdown]
# # Importing important libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("https://raw.githubusercontent.com/trupti1605/World-Happiness-report-/master/Data")

# %%
df.head(5)
# Out:
#        Country  Happiness Rank  Happiness Score   Economy    Family    Health  \
# 0       Norway               1            7.537  1.616463  1.533524  0.796667
# 1      Denmark               2            7.522  1.482383  1.551122  0.792566
# 2      Iceland               3            7.504  1.480633  1.610574  0.833552
# 3  Switzerland               4            7.494  1.564980  1.516912  0.858131
# 4      Finland               5            7.469  1.443572  1.540247  0.809158
#
#     Freedom  Generosity  Corruption  Dystopia  Job Satisfaction  \
# 0  0.635423    0.362012    0.315964  2.277027              94.6
# 1  0.626007    0.355280    0.400770  2.313707              93.5
# 2  0.627163    0.475540    0.153527  2.322715              94.5
# 3  0.620071    0.290549    0.367007  2.276716              93.7
# 4  0.617951    0.245483    0.382612  2.430182              91.2
#
#            Region
# 0  Western Europe
# 1  Western Europe
# 2  Western Europe
# 3  Western Europe
# ...

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 12 columns):
# Country             153 non-null object
# Happiness Rank      153 non-null int64
# Happiness Score     153 non-null float64
# Economy             153 non-null float64
# Family              153 non-null float64
# Health              153 non-null float64
# Freedom             153 non-null float64
# Generosity          153 non-null float64
# Corruption          153 non-null float64
# Dystopia            153 non-null float64
# Job Satisfaction    151 non-null float64
# Region              153 non-null object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.4+ KB

# %%
df.shape
# Out:
# (153, 12)

# %%
df.isnull().sum()
# Out:
# Country             0
# Happiness Rank      0
# Happiness Score     0
# Economy             0
# Family              0
# Health              0
# Freedom             0
# Generosity          0
# Corruption          0
# Dystopia            0
# Job Satisfaction    2
# Region              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score     Economy      Family      Health  \
# count      151.000000       151.000000  151.000000  151.000000  151.000000
# mean        77.827815         5.357874    0.983895    1.190509    0.550794
# std         44.934732         1.132826    0.420955    0.286371    0.236116
# min          1.000000         2.693000    0.000000    0.000000    0.000000
# 25%         39.500000         4.505500    0.663371    1.042635    0.369866
# 50%         78.000000         5.279000    1.064578    1.253918    0.606042
# 75%        116.500000         6.101500    1.314879    1.418162    0.715975
# max        155.000000         7.537000    1.870766    1.610574    0.949492
#
#           Freedom  Generosity  Corruption    Dystopia  Job Satisfaction
# count  151.000000  151.000000  151.000000  151.000000        151.000000
# mean     0.409805    0.244914    0.123008    1.854910         75.209934
# std      0.150144    0.135236    0.102776    0.502189         12.962365
# ...

# %% [markdown]
# # Barplot

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=df ['Happiness Rank'],y = df['Freedom'], palette = sns.cubehelix_palette(70))
plt.xticks(rotation = 90) # slope of the words in the x axis 
plt.xlabel('Happiness Rank')
plt.ylabel('Freedom')
plt.title('Happiness Rank vs Freedom')
plt.show()

# %%
df['Happiness Score'].head(10).plot(kind='barh',figsize=(10,10))

# %%
df['Job Satisfaction'].plot(kind='hist',bins=[40,50,60,70,80,90,100],figsize=(10,10))

# %% [markdown]
# # Scatterplot

# %%
sns.pairplot(data=df,kind='reg',size=5,x_vars=['Happiness Score'],y_vars=['Job Satisfaction'])
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Heatmap

# %%
corr = df.corr()
ax = sns.heatmap(corr, vmin=-1, vmax=1, center=0,
              cmap=sns.diverging_palette(20, 220, n=200),
                 square=True)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
# Out:
# [Text(0.5, 0, 'Happiness Rank'),
#  Text(1.5, 0, 'Happiness Score'),
#  Text(2.5, 0, 'Economy'),
#  Text(3.5, 0, 'Family'),
#  Text(4.5, 0, 'Health'),
#  Text(5.5, 0, 'Freedom'),
#  Text(6.5, 0, 'Generosity'),
#  Text(7.5, 0, 'Corruption'),
#  Text(8.5, 0, 'Dystopia'),
#  Text(9.5, 0, 'Job Satisfaction')]

# %% [markdown]
# # Joint plot

# %%
sns.jointplot(df['Happiness Score'],df['Job Satisfaction'],kind='kde',color='y',data=df)

# %% [markdown]
# # Factor plot

# %%
sns.factorplot(x="Happiness Score",y="Job Satisfaction",data=df,kind="bar",size=6)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/seaborn/categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Box plot

# %%
df.plot.box(sym='.k',figsize=(15,3))
plt.show ()

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# # Histogram

# %%
df.hist(bins=10,figsize=(20,20))
plt.show()

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(data=df, size = 5, hue='Region',
                  x_vars=['Happiness Score'],
                  y_vars=['Health'])
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df, hue = 'Job Satisfaction', vars = ['Happiness Score','Health'] )
sns.set(style="ticks")

# %% [markdown]
# # Violin plot

# %%
ax = sns.violinplot(x="Happiness Score", y="Job Satisfaction",
                    data=df, palette="muted")

# %%
f,axes=plt.subplots (1,1,figsize=(15,4))
sns.distplot(df['Job Satisfaction'],kde=True,hist=True,color="g")

# %%
f,axes = plt.subplots(1,1,figsize=(3,5),sharex = True,sharey =True)
s=np.linspace(0,3,10)
cmap = sns.cubehelix_palette(start=0.0, light=1, as_cmap=True)

x = df['Happiness Score'].values
y = df['Job Satisfaction'].values
sns.kdeplot(x,y,cmap=cmap,shade=True,cut = 5)

# %%
# Dataframe of the Happiness Score
Happiness_Score= pd.DataFrame(df["Happiness Score"])
Happiness_Score.describe()
# Out:
#        Happiness Score
# count       151.000000
# mean          5.357874
# std           1.132826
# min           2.693000
# 25%           4.505500
# 50%           5.279000
# 75%           6.101500
# max           7.537000

# %%
# Add our Happiness Category into the Happiness_Score dataframe
happiness=[]
for i in Happiness_Score["Happiness Score"]:
    if i<5.5:
        happiness.append("UNHAPPY")
    else:
        happiness.append("HAPPY")

# Join our Hapiness_Score dataframe into the main dataframe
predicted_happiness = pd.DataFrame(happiness,columns=["PREDICTED_HAPPINESS"])
predicted_happiness = pd.DataFrame(predicted_happiness["PREDICTED_HAPPINESS"].astype('category'))

data = pd.concat([df,predicted_happiness],axis=1)

# %%
predicted_happiness["PREDICTED_HAPPINESS"].value_counts()
# Out:
# UNHAPPY    84
# HAPPY      67
# Name: PREDICTED_HAPPINESS, dtype: int64

# %%
f, axes = plt.subplots(1, 1, figsize=(5, 4))
sns.countplot(predicted_happiness["PREDICTED_HAPPINESS"])
plt.xlabel("Predicted Happiness")
plt.ylabel("Number of Countries")
# Out:
# Text(0, 0.5, 'Number of Countries')

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz

# %%
# Remove any duplicate columns (if any)
data = data.loc[:,~data.columns.duplicated()]
data.shape
#y=pd.DataFrame(data["PREDICTED_HAPPINESS"])
#y.shape
# Out:
# (153, 13)

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Country                0
# Happiness Rank         0
# Happiness Score        0
# Economy                0
# Family                 0
# Health                 0
# Freedom                0
# Generosity             0
# Corruption             0
# Dystopia               0
# Job Satisfaction       0
# Region                 0
# PREDICTED_HAPPINESS    0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# Country             0
# Happiness Rank      0
# Happiness Score     0
# Economy             0
# Family              0
# Health              0
# Freedom             0
# Generosity          0
# Corruption          0
# Dystopia            0
# Job Satisfaction    0
# Region              0
# dtype: int64

# %%
#y=pd.DataFrame(data["predicted_happiness"])
y=predicted_happiness
y.shape
# Out:
# (151, 1)

# %%
x=df.drop(['Country','Region','Happiness Score'],axis = 1)

# %%
x.head()
# Out:
#    Happiness Rank   Economy    Family    Health   Freedom  Generosity  \
# 0               1  1.616463  1.533524  0.796667  0.635423    0.362012
# 1               2  1.482383  1.551122  0.792566  0.626007    0.355280
# 2               3  1.480633  1.610574  0.833552  0.627163    0.475540
# 3               4  1.564980  1.516912  0.858131  0.620071    0.290549
# 4               5  1.443572  1.540247  0.809158  0.617951    0.245483
#
#    Corruption  Dystopia  Job Satisfaction
# 0    0.315964  2.277027              94.6
# 1    0.400770  2.313707              93.5
# 2    0.153527  2.322715              94.5
# 3    0.367007  2.276716              93.7
# 4    0.382612  2.430182              91.2

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Random Forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier 
ran_class=RandomForestClassifier()
ran_class.fit(x_train,y_train)
ran_predict=ran_class.predict(x_test)
print(classification_report(y_test,ran_predict))
accuracy3=ran_class.score(x_test,y_test)
print(accuracy3*100,'%')
# Out:
#               precision    recall  f1-score   support
#
#        HAPPY       0.93      1.00      0.97        14
#      UNHAPPY       1.00      0.94      0.97        17
#
#    micro avg       0.97      0.97      0.97        31
#    macro avg       0.97      0.97      0.97        31
# weighted avg       0.97      0.97      0.97        31
#
# 96.7741935483871 %
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import classification_report, confusion_matrix
logistic = LogisticRegression()
logistic.fit(x_train,y_train)
y_pred=logistic.predict(x_test)
print(classification_report(y_test,y_pred))
accuracy=logistic.score(x_test,y_test)
print(accuracy*100,'%')
# Out:
#               precision    recall  f1-score   support
#
#        HAPPY       0.93      0.93      0.93        14
#      UNHAPPY       0.94      0.94      0.94        17
#
#    micro avg       0.94      0.94      0.94        31
#    macro avg       0.93      0.93      0.93        31
# weighted avg       0.94      0.94      0.94        31
#
# 93.54838709677419 %
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes  import GaussianNB 
from sklearn.metrics import classification_report, confusion_matrix
nvclassifier = GaussianNB ()
nvclassifier .fit(x_train,y_train)
y_pred=nvclassifier .predict(x_test)
print(classification_report(y_test,y_pred))
acc=nvclassifier.score(x_test,y_test)
print(acc*100,'%')
# Out:
#               precision    recall  f1-score   support
#
#        HAPPY       0.93      1.00      0.97        14
#      UNHAPPY       1.00      0.94      0.97        17
#
#    micro avg       0.97      0.97      0.97        31
#    macro avg       0.97      0.97      0.97        31
# weighted avg       0.97      0.97      0.97        31
#
# 96.7741935483871 %
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
